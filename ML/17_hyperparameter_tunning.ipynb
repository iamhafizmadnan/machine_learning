# %% [markdown]
# # Hyperparameter tuning:
# Hyperparameter tuning is the process of finding the best set of hyperparameters for a machine learning model. Hyperparameters are parameters that are not learned from the data, but are set by the user before training the model. Examples of hyperparameters include learning rate, number of trees in a random forest, and regularization strength.
#
# - Types:
# - `Grid Search:` This method exhaustively searches through a specified subset of hyperparameters. It evaluates the model for each combination of hyperparameters and selects the best one based on a performance metric.
# - `Random Search:` This method randomly samples hyperparameters from a specified distribution. It is more efficient than grid search, especially when the hyperparameter space is large.
# - ` Bayesian Optimization:` This method builds a probabilistic model of the objective function and uses it to select the most promising hyperparameters to evaluate in the true objective function. It is more efficient than random search and grid search, especially when the evaluation of the objective function is expensive.
# - `Gradient-based Optimization:` This method uses gradient information to optimize hyperparameters. It is typically used for optimizing continuous hyperparameters, such as learning rate.
# - `Evolutionary Algorithms:` This method uses evolutionary strategies to optimize hyperparameters. It is inspired by the process of natural selection and is particularly useful for optimizing discrete hyperparameters.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split , GridSearchCV
from sklearn.metrics import accuracy_score , classification_report , confusion_matrix

# %%
from sklearn.datasets import load_iris
import pandas as pd

# %%
iris = load_iris()
X = iris.data
y = iris.target

# %%
# define the model
model = RandomForestClassifier()


# TRAIN the parameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# set up the grid 
grid = GridSearchCV(estimator=model, 
                    param_grid=param_grid, 
                    cv=5,
                      n_jobs=-1,
                        verbose=2)

# %%
# fit the model
grid.fit(X, y)

# print the best parameters
print("Best Hyperparameters:", grid.best_params_)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Best Hyperparameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}

# %%
# define the model
from sklearn.model_selection import RandomizedSearchCV
model = RandomForestClassifier()


# TRAIN the parameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'criterion': ['gini', 'entropy'],
    'bootstrap': [True, False],
}
# set up the grid 
grid = RandomizedSearchCV(
    estimator=model, 
    param_distributions=param_grid, 
    n_iter=10, 
    cv=5,
    n_jobs=-1,
    verbose=2
)


# fit the model
grid.fit(X, y)

# print the best parameters
print("Best Hyperparameters:", grid.best_params_)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 # define the model
#       2 from sklearn.model_selection import RandomizedSearchCV
# ----> 3 model = RandomizedSearchCV()
#       6 # TRAIN the parameter grid
#       7 param_grid = {
#       8     'n_estimators': [100, 200, 300],
#       9     'max_depth': [None, 10, 20, 30],
#      10     'criterion': ['gini', 'entropy'],
#      11     'bootstrap': [True, False],
#      12 }
#
# TypeError: RandomizedSearchCV.__init__() missing 2 required positional arguments: 'estimator' and 'param_distributions'
