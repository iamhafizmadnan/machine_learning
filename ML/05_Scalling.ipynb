# %% [markdown]
# Standard Scalling is a feature-scaling technique (also called **z-score normalization**) that transforms numerical features so they have:
#
# - **Mean = 0**
# - **Standard Deviation = 1**
#
# This helps models perform better when features are on different scales, especially for **KNN, SVM, PCA, Logistic Regression,** and **Neural Networks**.
#
# Formula: `z = (x - μ) / σ`
# Standard Scalling is

# %%
# import libraries
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, MaxAbsScaler

# %%
df = {
    "age": [25, 30, 35, 40, 45],
    "income": [50000, 60000, 70000, 80000, 90000],
    "height": [160, 165, 170, 175, 180]
}

df = pd.DataFrame(df)
df
# Out:
#    age  income  height
# 0   25   50000     160
# 1   30   60000     165
# 2   35   70000     170
# 3   40   80000     175
# 4   45   90000     180

# %%
# import the scaler
scaler = StandardScaler()
# fit the scaler to the data
scaler.fit(df)

scaled_data = scaler.transform(df)
scaled_data
# Out:
# array([[-1.41421356, -1.41421356, -1.41421356],
#        [-0.70710678, -0.70710678, -0.70710678],
#        [ 0.        ,  0.        ,  0.        ],
#        [ 0.70710678,  0.70710678,  0.70710678],
#        [ 1.41421356,  1.41421356,  1.41421356]])

# %% [markdown]
# # Min -Max-Scaler

# %%
scaler = MinMaxScaler()
scaler.fit(df)
scaled_data = scaler.transform(df)      
scaled_data
# Out:
# array([[0.  , 0.  , 0.  ],
#        [0.25, 0.25, 0.25],
#        [0.5 , 0.5 , 0.5 ],
#        [0.75, 0.75, 0.75],
#        [1.  , 1.  , 1.  ]])

# %% [markdown]
# # Max- Absolute-Scaler

# %%
scaler = MaxAbsScaler()
scaler.fit(df)  
scaled_data = scaler.transform(df)
scaled_data
# Out:
# array([[0.55555556, 0.55555556, 0.88888889],
#        [0.66666667, 0.66666667, 0.91666667],
#        [0.77777778, 0.77777778, 0.94444444],
#        [0.88888889, 0.88888889, 0.97222222],
#        [1.        , 1.        , 1.        ]])
