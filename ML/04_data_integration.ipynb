# %% [markdown]
# # Data Merge

# %%
import pandas as pd

data1 = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35],
    'id': [1, 2, 3]
}

df1 = pd.DataFrame(data1)

data2 = {
    "id": [1, 2, 3],
    "City": ["New York", "Los Angeles", "Chicago"],
    'occupation': ['Engineer', 'Doctor', 'Artist']
}

df2 = pd.DataFrame(data2)   

merged_df = pd.merge(df1, df2, on='id', how='inner')
print(merged_df)
# Out:
#       Name  Age  id         City occupation
# 0    Alice   25   1     New York   Engineer
# 1      Bob   30   2  Los Angeles     Doctor
# 2  Charlie   35   3      Chicago     Artist

# %% [markdown]
# ---
# # Concatenation

# %%
import pandas as pd

data1 = {'Name': ['Alice', 'Bob', 'Charlie'],
         'Age': [25, 30, 35],
         'id': [1, 2, 3]}

df1 = pd.DataFrame(data1)

data2 = {'id': [1, 2, 3],
            'City': ['New York', 'Los Angeles', 'Chicago'],
            'occupation': ['Engineer', 'Doctor', 'Artist']}


df2 = pd.DataFrame(data2)



concat_df = pd.concat([df1, df2], axis=1)   
print(concat_df)


concat_df = pd.concat([df1, df2], axis=0)
print(concat_df)
# Out:
#       Name  Age  id  id         City occupation
# 0    Alice   25   1   1     New York   Engineer
# 1      Bob   30   2   2  Los Angeles     Doctor
# 2  Charlie   35   3   3      Chicago     Artist
#       Name   Age  id         City occupation
# 0    Alice  25.0   1          NaN        NaN
# 1      Bob  30.0   2          NaN        NaN
# 2  Charlie  35.0   3          NaN        NaN
# 0      NaN   NaN   1     New York   Engineer
# 1      NaN   NaN   2  Los Angeles     Doctor
# 2      NaN   NaN   3      Chicago     Artist
