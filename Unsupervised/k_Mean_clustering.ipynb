# %% [markdown]
# # K-Mean Clustering
#
# - It is unsupervised learning algorithm
# - It works on unlabelled data
# - It make clusters from unlabelled data
# - It is a centroid based algorithm
# - It is a partitioning based algorithm
# - It is a distance based algorithm
# - It is a iterative algorithm
# -

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from  sklearn.datasets import make_blobs

# generate sample data
x, y = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)

# initian a kmean object with the number of clusters
kmean = KMeans(n_clusters=4)

# fit the model
kmean.fit(x)

# get the predicted cluster label
labels = kmean.labels_
# plot the data point with different color for different cluster
plt.scatter(x[:, 0], x[:, 1], c=labels)
# plt.tittle('K-Mean Clustering')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %% [markdown]
# # lets practice on diamond dataset

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

df = sns.load_dataset('diamonds')
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
X = df[['carat', 'price']]

kmeans = KMeans(n_clusters=5)

kmeans.fit(X)

# get the predicted cluster label
labels = kmeans.labels_

df['labels'] = labels

#plot the data point with different color for different cluster
plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=labels)
plt.xlabel('Carat')
plt.ylabel('Price')
plt.title('K-Mean Clustering of Diamonds')
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

df = sns.load_dataset('diamonds')
X = df[['carat', 'price','cut', 'color', 'clarity']]

X = pd.get_dummies(X)

kmeans = KMeans(n_clusters=5)
 
kmeans.fit(X)

labels = kmeans.labels_

df['labels'] = labels

plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=labels)
plt.xlabel('Carat')
plt.ylabel('Price') 
plt.title('K-Mean Clustering of Diamonds')
plt.show()

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  labels
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43       0
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31       0
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31       0
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63       0
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75       0

# %%
# adding cluster labels to  the data for further analysis

X = df[['carat', 'price']]

kmeans = KMeans(n_clusters=3)
kmeans.fit(X)

labels = kmeans.predict(X)

df ['labels' ] = labels

print(df.head())

print("These are the unique value  of labels: ,sorted: ", sorted(df['labels'].unique()))
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  labels
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43       1
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31       1
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31       1
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63       1
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75       1
# These are the unique value  of labels: ,sorted:  [np.int32(0), np.int32(1), np.int32(2)]

# %% [markdown]
# # Model Evalution

# %%
# Elbow method
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# load the dataset
df = sns.load_dataset('diamonds')

# convert float to int
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
#convet into int
df['carat'] = df['carat'].astype(int)
df['depth'] = df['depth'].astype(int)

# %%
df.dtypes
# Out:
# carat         int64
# cut        category
# color      category
# clarity    category
# depth         int64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
feature =['carat', 'price']

x = df[feature]
k_values = range(1, 11)

inertia = []
for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(x)
    inertia.append(kmeans.inertia_)

plt.plot(k_values, inertia, 'bo-')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal k')
plt.xticks(k_values)
plt.grid()
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

df = sns.load_dataset('diamonds')

feature =['carat', 'price', 'depth']

x = df[feature]
k_values = range(1, 11)

inertia = []
for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(x)
    inertia.append(kmeans.inertia_)

plt.plot(k_values, inertia, 'bo-')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal k')


# find the elbow point
diff = [inertia[i] - inertia[i+1] for i in range(len(inertia)-1)]
best_k = diff.index(max(diff)) + 2
print("Optimal number of clusters (k): ", best_k)

# add a vertical line to indiate the elbow point
plt.axvline(x=best_k, color='r', linestyle='--', label= 'Elbow Point')

plt.legend()
plt.show()

print("The best number of clusters is: ", best_k)
# Out:
# Optimal number of clusters (k):  2
# The best number of clusters is:  2

# %% [markdown]
# # 2. Silhouette Score

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.metrics import silhouette_score

# laod the dataset
df = sns.load_dataset('diamonds')

# select relevant features for clustering
feature = ['carat', 'price']
X = df[feature]

# peform k-means clustering for different values of k
k_values = range(2, 11)
silhouette_scores = []

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    labels = kmeans.labels_
    score = silhouette_score(X, labels)
    silhouette_scores.append(score)

# plot silhouette scores for different values of k
plt.plot(k_values, silhouette_scores, 'bo-')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score for Different k')
plt.xticks(k_values)
plt.grid()
plt.show()
